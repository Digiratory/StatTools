# %% [markdown]
# # FBN Generator Validation
#
# **Description**
#
# An algorithm for generating fractional Brownian noise (FBN) with a given Hurst exponent.

# %%
import numpy as np
import math
from scipy import stats
from tqdm import tqdm
from itertools import islice

from StatTools.analysis.dpcca import dpcca
from StatTools.generators.hurst_generator import HurstGenerator, normalize

# %%
valdata = {
    "h_list": [i * 0.01 for i in range(10, 210, 10)],
    "base_list": [i*0.01 for i in range(105, 201, 5)],
}
S = np.array([2**i for i in range(3, 9)])
STEP = 1
TARGET_LEN = 4000

# %%
def get_test_h(
    base: float, filter_len: int, h: float, S: np.ndarray, step: int
) -> float:
    """
    Calculates the Hurst exponent for the generated trajectory.

    Parameters:
        base: The base of the number system for bins
        filter_len: Filter length
        h: The specified Hurst exponent
        S: Scales for analysis
        step: The step for analysis

    Returns:
        Calculated Hurst exponent (h_gen)
    """
    generator = HurstGenerator(h, filter_len, base)
    trj = []
    for value in islice(generator, TARGET_LEN):
        trj.append(value)

    Z = normalize(np.array(trj[::-1]))
    _, _, f_z, s_z = dpcca(Z, 2, step, S, processes=1, n_integral=0)
    f_z = np.sqrt(f_z)
    f_z /= f_z[0]
    res = stats.linregress(np.log(s_z), np.log(f_z)).slope
    return res

# %%
def val_generator(H_list, base_list, S, step, target_len=4000):
    data = {
    'base': [],
    'h': [],
    'h_test': [],
    'filter_len': []
    }
    input_data_map = {}
    for base in base_list:
        input_data_map[base] = int(math.log(target_len, base))
    for base in tqdm(base_list):
        for h in H_list:
            filter_len = input_data_map.get(base, 0)
            h_test = get_test_h(base, filter_len, h, S, step)
            data['base'].append(round(base, 2))
            data['h'].append(round(h, 2))
            data['h_test'].append(h_test)
            data['filter_len'].append(filter_len)
    return data

# %%
data = val_generator(valdata["h_list"], valdata["base_list"], S, STEP)
# Out:
# 100%|██████████| 20/20 [01:04<00:00,  3.23s/it]

# %% [markdown]
# ## Plot results

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
df = pd.DataFrame(data)
df['error'] = (df['h_test'] - df['h']).abs()
pivot_table = df.pivot_table(index='h', columns='base', values='error', aggfunc='mean')

# %%
fontsize=14
sns.set(style='white')
fig = plt.figure(figsize=(16, 16), dpi= 80)
grid = plt.GridSpec(4, 4, hspace=0.5, wspace=0.2)
ax_main = fig.add_subplot(grid[:-1, :-1])
ax_bottom = fig.add_subplot(grid[-1, 0:-1], yticklabels=[])

sns.heatmap(pivot_table, annot=True, fmt=".3f", cmap='magma', ax=ax_main, cbar_kws = dict(use_gridspec=False,location="top"))
ax_bottom.set(title='', ylabel='Filter len', xlabel='')
sns.barplot(data=data, x='base', y='filter_len', ax=ax_bottom, color='indigo')
ax_bottom.bar_label(ax_bottom.containers[0], fontsize=fontsize, color = 'white')
ax_bottom.set_xticklabels([])
ax_bottom.set_xlabel('')
ax_bottom.invert_yaxis()

ax_main.set(title='Generator h-Test', ylabel='h', xlabel='Base')
ax_main.title.set_fontsize(fontsize)
for item in ([ax_main.xaxis.label, ax_main.yaxis.label] + ax_main.get_xticklabels() + ax_main.get_yticklabels()):
    item.set_fontsize(fontsize)
for item in ([ax_bottom.xaxis.label, ax_bottom.yaxis.label] + ax_bottom.get_xticklabels() + ax_bottom.get_yticklabels()):
    item.set_fontsize(fontsize)
plt.show()

# %%
results = df.groupby('base').apply(
    lambda x: pd.Series({
        'MSE': mean_squared_error(x['h'], x['h_test']),
        'MAE': mean_absolute_error(x['h'], x['h_test'])
    }), include_groups=False
).reset_index()

# %%
plt.figure(figsize=(10, 6))

plt.subplot(2, 1, 1)
sns.barplot(x='base', y='MSE', hue='MSE', legend=False, data=results, palette='magma')
plt.xlabel('base')
plt.ylabel('MSE')

plt.subplot(2, 1, 2)
sns.barplot(x='base', y='MAE', hue='MAE', legend=False, data=results, palette='magma')
plt.xlabel('base')
plt.ylabel('MAE')
plt.tight_layout()
plt.show()
